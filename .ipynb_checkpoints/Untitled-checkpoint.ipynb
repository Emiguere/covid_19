# %% [markdown]
# # COVID 19

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading data

# %%
df = pd.read_csv('data_06_10_2020')

# %%
df.shape
# Out:
# (47271, 12)

# %%
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  06/10/2020    6     10  2020    145       5             Afghanistan    AF
# 1  05/10/2020    5     10  2020     44       0             Afghanistan    AF
# 2  04/10/2020    4     10  2020      7       4             Afghanistan    AF
# 3  03/10/2020    3     10  2020      5       0             Afghanistan    AF
# 4  02/10/2020    2     10  2020     17       0             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           1.083020
# 1                                           0.780721
# ...

# %%
df['countriesAndTerritories'].nunique()
# Out:
# 210

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47271 entries, 0 to 47270
# Data columns (total 12 columns):
# dateRep                                                       47271 non-null object
# day                                                           47271 non-null int64
# month                                                         47271 non-null int64
# year                                                          47271 non-null int64
# cases                                                         47271 non-null int64
# deaths                                                        47271 non-null int64
# countriesAndTerritories                                       47271 non-null object
# geoId                                                         47065 non-null object
# countryterritoryCode                                          47207 non-null object
# popData2019                                                   47207 non-null float64
# ...

# %%
df['date_casted']=pd.to_datetime(df['dateRep'])

# %%
Spain = df[df['countriesAndTerritories']=='Spain']

# %%
f=plt.figure(figsize=(10, 10))
sns.set_style("whitegrid")
sns.lineplot(x='date_casted',y='deaths',hue='continentExp',dashes=False,alpha=1,data=df)
